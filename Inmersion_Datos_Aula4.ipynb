# %% [markdown]
# <a href="https://colab.research.google.com/github/KitzelZ/Inmersion-Datos/blob/main/Inmersion_Datos_Aula4.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# #**Aula 1**

# %% [markdown]
# Conectar colab con drive

# %%
from google.colab import drive

drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %% [markdown]
# Importar librerias y DataSet

# %%
import pandas as pd

import matplotlib.pyplot as plt
import seaborn as sns

# %%
inmuebles = pd.read_csv('/content/drive/MyDrive/Inmersion Datos/inmuebles_bogota.csv')
inmuebles.head()
# Out:
#           Tipo                                 Descripcion  Habitaciones  \
# 0  Apartamento  Apartamento en venta en Zona Noroccidental             3
# 1         Casa                   Casa en venta en Castilla             4
# 2  Apartamento     Apartamento en venta en Chico Reservado             3
# 3  Apartamento             Apartamento en venta en Usaquén             3
# 4  Apartamento         Apartamento en venta en Bella Suiza             2
#
#    Baños  Área              Barrio                                    UPZ  \
# 0      2    70  Zona Noroccidental     CHAPINERO: Pardo Rubio + Chapinero
# 1      3   170            Castilla            KENNEDY: Castilla + Bavaria
# 2      3   144     Chico Reservado     CHAPINERO: Chicó Lago + El Refugio
# 3      2   154             Usaquén                                Usaquén
# 4      3   128         Bella Suiza  USAQUÉN: Country Club + Santa Bárbara
#
#              Valor
# 0    $ 360.000.000
# 1    $ 670.000.000
# 2  $ 1.120.000.000
# ...

# %% [markdown]
# #   Analisis Exploratorio de Datos

# %%
inmuebles.shape #Tabla cantidad de datos
# Out:
# (9520, 8)

# %%
inmuebles.columns #Columnas
# Out:
# Index(['Tipo', 'Descripcion', 'Habitaciones', 'Baños', 'Área', 'Barrio', 'UPZ',
#        'Valor'],
#       dtype='object')

# %% [markdown]
# Renombrar columnas

# %%
columnas = {'Baños':'Banos', 'Área':'Area'}
inmuebles = inmuebles.rename(columns=columnas)
inmuebles.sample(10) #sample trae datos en orden random del DF
# Out:
#              Tipo                            Descripcion  Habitaciones  Banos  \
# 7397  Apartamento   Apartamento en venta en Gran Granada             3      2
# 7209  Apartamento      Apartamento en venta en Chapinero             3      2
# 4091  Apartamento        Apartamento en venta en Usaquén             3      3
# 4529  Apartamento           Apartamento en venta en Suba             3      1
# 3012  Apartamento    Apartamento en venta en Los Rosales             2      3
# 4179         Casa    Casa en venta en Zona Noroccidental             3      3
# 820   Apartamento    Apartamento en venta en Teusaquillo             2      2
# 2794  Apartamento           Apartamento en venta en Bosa             3      2
# 4751         Casa                  Casa en venta en Suba             3      3
# 8541  Apartamento  Apartamento en venta en Santa Barbara             1      2
#
#       Area              Barrio                                    UPZ  \
# ...

# %%
inmuebles.info() #Info DataSet
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 9520 entries, 0 to 9519
# Data columns (total 8 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   Tipo          9520 non-null   object
#  1   Descripcion   9520 non-null   object
#  2   Habitaciones  9520 non-null   int64
#  3   Banos         9520 non-null   int64
#  4   Area          9520 non-null   int64
#  5   Barrio        9520 non-null   object
#  6   UPZ           9478 non-null   object
#  7   Valor         9520 non-null   object
# dtypes: int64(3), object(5)
# memory usage: 595.1+ KB

# %%
inmuebles.iloc[300] #localizar indice --> iloc
# Out:
# Tipo                                Apartamento
# Descripcion     Apartamento en venta en Kennedy
# Habitaciones                                  2
# Banos                                         1
# Area                                         42
# Barrio                                  Kennedy
# UPZ                             Kennedy Central
# Valor                             $ 116.100.000
# Name: 300, dtype: object

# %%
inmuebles.iloc[300:305] #notacion por trozos
# Out:
#             Tipo                          Descripcion  Habitaciones  Banos  \
# 300  Apartamento      Apartamento en venta en Kennedy             2      1
# 301  Apartamento  Apartamento en venta en Chico Norte             2      2
# 302  Apartamento      Apartamento en venta en Kennedy             3      2
# 303  Apartamento      Apartamento en venta en Kennedy             3      2
# 304  Apartamento     Apartamento en venta en Cedritos             4      4
#
#      Area       Barrio                                 UPZ          Valor
# 300    42      Kennedy                     Kennedy Central  $ 116.100.000
# 301    95  Chico Norte  CHAPINERO: Chicó Lago + El Refugio  $ 980.000.000
# 302    54      Kennedy                     Kennedy Central  $ 237.000.000
# 303    67      Kennedy                     Kennedy Central  $ 320.000.000
# 304   132     Cedritos                             Usaquén  $ 530.000.000

# %%
inmuebles['Valor'][300] # otro ejemplo de notacion por trozos
# Out:
# '$ 116.100.000'

# %%
inmuebles['Valor'][300:305] # más ejemplos de notacion por trozos
# Out:
# 300    $ 116.100.000
# 301    $ 980.000.000
# 302    $ 237.000.000
# 303    $ 320.000.000
# 304    $ 530.000.000
# Name: Valor, dtype: object

# %%
type(inmuebles['Valor'][300:305])
# Out:
# pandas.core.series.Series

# %% [markdown]
# Calculo del Área

# %%
inmuebles.Area.mean()
# Out:
# 146.66470588235293

# %% [markdown]
# Inmuebles de un Barrio

# %%
inmuebles.sample(100)
# Out:
#              Tipo                              Descripcion  Habitaciones  \
# 4520  Apartamento  Apartamento en venta en Chico Reservado             3
# 4409  Apartamento   Apartamento en venta en Barrios Unidos             3
# 6621  Apartamento          Apartamento en venta en Usaquén             3
# 2190  Apartamento      Apartamento en venta en Los Rosales             3
# 3424         Casa               Casa en venta en Chapinero             5
# ...           ...                                      ...           ...
# 6933         Casa                 Casa en venta en Modelia             3
# 9420  Apartamento          Apartamento en venta en Usaquén             3
# 3758         Casa                 Casa en venta en Usaquén             3
# 3862  Apartamento          Apartamento en venta en Kennedy             2
# 934   Apartamento      Apartamento en venta en Bella Suiza             1
#
#       Banos  Area           Barrio                                    UPZ  \
# ...

# %%
(inmuebles.Barrio == 'El Batán')
# Out:
# 0       False
# 1       False
# 2       False
# 3       False
# 4       False
#         ...
# 9515    False
# 9516    False
# 9517    False
# 9518    False
# 9519    False
# Name: Barrio, Length: 9520, dtype: bool

# %% [markdown]
# Cantidad de inmuebles que hay en el Barrio

# %%
sum((inmuebles.Barrio == 'El Batán'))
# Out:
# 133

# %% [markdown]
# Variable del Barrio

# %%
inmuebles_Batan = (inmuebles.Barrio == 'El Batán')
type(inmuebles_Batan)
# Out:
# pandas.core.series.Series

# %% [markdown]
# DataFrame del Barrio

# %%
El_Batan = inmuebles[inmuebles_Batan]
El_Batan
# Out:
#              Tipo                       Descripcion  Habitaciones  Banos  \
# 44    Apartamento  Apartamento en venta en El Batán             3      3
# 71    Apartamento  Apartamento en venta en El Batán             3      3
# 268   Apartamento  Apartamento en venta en El Batán             2      2
# 271   Apartamento  Apartamento en venta en El Batán             2      2
# 339   Apartamento  Apartamento en venta en El Batán             2      2
# ...           ...                               ...           ...    ...
# 9233         Casa         Casa en venta en El Batán             4      3
# 9252  Apartamento  Apartamento en venta en El Batán             2      2
# 9344  Apartamento  Apartamento en venta en El Batán             3      2
# 9445  Apartamento  Apartamento en venta en El Batán             3      2
# 9504  Apartamento  Apartamento en venta en El Batán             2      2
#
#       Area    Barrio          UPZ            Valor
# ...

# %% [markdown]
# Area promedio del Barrio seleccionado

# %%
El_Batan.Area.mean()
# Out:
# 106.65413533834587

# %% [markdown]
# Relacion Barrios - Inmuebles

# %%
len(inmuebles.Barrio.value_counts()) #Cantidad de Barrios
# Out:
# 149

# %%
inmuebles.Barrio.value_counts() #Inmuebles en Barrios
# Out:
# Usaquén               1105
# Zona Noroccidental     877
# Bosa                   589
# Kennedy                589
# Cedritos               554
#                       ...
# Colinas De Suba          1
# La Estanzuela            1
# Roma                     1
# Alameda                  1
# Prado Veraniego          1
# Name: Barrio, Length: 149, dtype: int64

# %%
len(inmuebles.UPZ.value_counts()) #Cantidad de UPZ
# Out:
# 63

# %% [markdown]
# Cantidad de inmuebles por barrio

# %%
inmuebles_barrio = inmuebles.Barrio.value_counts()
inmuebles_barrio.head(10).plot.bar()
# Out:
# <Axes: >

# %% [markdown]
# # **Desafío:**
#
# 1.   Promedio de área de todos los inmuebles en los barrios en el dataset. El top 10.
#
# 2.   Consultar otros datos estadísticos, conteo, mediana, valores mínimo y máximo.

# %%
inmuebles[['Barrio','Area']].groupby(['Barrio']).mean().sort_values(by=['Area'], ascending=False).head(10).plot(kind='bar')
# Out:
# <Axes: xlabel='Barrio'>

# %%
promedio_area = inmuebles[['Barrio','Area']].groupby(['Barrio']).mean().sort_values(by=['Area'], ascending=False).head(10)
promedio_area.plot(kind='bar', color='pink')

plt.xlabel('Barrio')
plt.ylabel('Área promedio')
plt.title('Promedio de Área de Inmuebles')
plt.show()

# %%
inmuebles.describe()
# Out:
#        Habitaciones   Banos      Area
# count       9520.00 9520.00   9520.00
# mean           3.07    2.45    146.66
# std            2.05    1.26   1731.38
# min            1.00    0.00      2.00
# 25%            2.00    2.00     57.00
# 50%            3.00    2.00     80.00
# 75%            3.00    3.00    135.00
# max          110.00    9.00 166243.00

# %% [markdown]
# # **Aula 2**

# %% [markdown]
# * Se utiliza ***split*** para separar $ de la cantidad
# *   ***str*** se utiliza para trabajar como string (en una lista) ya que es un pandas.series

# %%
inmuebles.Valor.str.split()
# Out:
# 0         [$, 360.000.000]
# 1         [$, 670.000.000]
# 2       [$, 1.120.000.000]
# 3         [$, 890.000.000]
# 4         [$, 970.000.000]
#                ...
# 9515      [$, 290.000.000]
# 9516      [$, 670.000.000]
# 9517      [$, 900.000.000]
# 9518      [$, 335.000.000]
# 9519      [$, 144.990.000]
# Name: Valor, Length: 9520, dtype: object

# %%
type(inmuebles.Valor.str.split())
# Out:
# pandas.core.series.Series

# %% [markdown]
# Usando el parametro ***expand=True*** me devuelve un formato de DataFrame

# %%
inmuebles.Valor.str.split(expand=True)
# Out:
#       0              1
# 0     $    360.000.000
# 1     $    670.000.000
# 2     $  1.120.000.000
# 3     $    890.000.000
# 4     $    970.000.000
# ...  ..            ...
# 9515  $    290.000.000
# 9516  $    670.000.000
# 9517  $    900.000.000
# 9518  $    335.000.000
# 9519  $    144.990.000
#
# [9520 rows x 2 columns]

# %% [markdown]
# Se almacena en una variable y se agregan estas dos columnas al DataFrame

# %%
valor = inmuebles.Valor.str.split(expand=True)
inmuebles['Moneda']= valor[0] #Columna 0 -> Moneda en DF
inmuebles['Precio']=valor[1] #Columna 1 -> Precio en DF
inmuebles.sample(3)
# Out:
#              Tipo                        Descripcion  Habitaciones  Banos  \
# 5554  Apartamento    Apartamento en venta en Usaquén             3      3
# 2404  Apartamento  Apartamento en venta en Chapinero             1      2
# 9218         Casa          Casa en venta en Engativa             3      4
#
#       Area     Barrio                                 UPZ            Valor  \
# 5554    66    Usaquén                             Usaquén    $ 261.500.000
# 2404    57  Chapinero  CHAPINERO: Pardo Rubio + Chapinero    $ 395.000.000
# 9218   640   Engativa                            Engativá  $ 1.500.000.000
#
#      Moneda         Precio
# 5554      $    261.500.000
# 2404      $    395.000.000
# 9218      $  1.500.000.000

# %% [markdown]
# Convertir los datos de la columna Precio de str a numerico
#
#
# *   Quitar el separador "." utilizando .replace (regex=True se agrega por actualizacion de python)
# *   Convertir str a float, utilizando **astype** en un nuevo atributo Precio Millon

# %%
inmuebles['Precio'] = inmuebles['Precio'].str.replace('.','',regex=True)

# %%
inmuebles['Precio_Millon'] = inmuebles.Precio.astype(float)/1000000
inmuebles.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 9520 entries, 0 to 9519
# Data columns (total 11 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Tipo           9520 non-null   object
#  1   Descripcion    9520 non-null   object
#  2   Habitaciones   9520 non-null   int64
#  3   Banos          9520 non-null   int64
#  4   Area           9520 non-null   int64
#  5   Barrio         9520 non-null   object
#  6   UPZ            9478 non-null   object
#  7   Valor          9520 non-null   object
#  8   Moneda         9520 non-null   object
#  9   Precio         9520 non-null   object
#  10  Precio_Millon  9520 non-null   float64
# dtypes: float64(1), int64(3), object(7)
# memory usage: 818.2+ KB

# %%
inmuebles.describe()
# Out:
#        Habitaciones   Banos      Area  Precio_Millon
# count       9520.00 9520.00   9520.00        9520.00
# mean           3.07    2.45    146.66         602.06
# std            2.05    1.26   1731.38         704.60
# min            1.00    0.00      2.00          60.00
# 25%            2.00    2.00     57.00         250.00
# 50%            3.00    2.00     80.00         409.18
# 75%            3.00    3.00    135.00         680.00
# max          110.00    9.00 166243.00       16000.00

# %% [markdown]
# Eliminar posiciones decimales

# %%
pd.set_option('display.precision',2)
pd.set_option('display.float_format', lambda x: '%.2f' % x)
inmuebles.describe()
# Out:
#        Habitaciones   Banos      Area  Precio_Millon
# count       9520.00 9520.00   9520.00        9520.00
# mean           3.07    2.45    146.66         602.06
# std            2.05    1.26   1731.38         704.60
# min            1.00    0.00      2.00          60.00
# 25%            2.00    2.00     57.00         250.00
# 50%            3.00    2.00     80.00         409.18
# 75%            3.00    3.00    135.00         680.00
# max          110.00    9.00 166243.00       16000.00

# %% [markdown]
# # Inconsitencias en los datos
#
# Se busca ver la informacion de ciertos inmuebles debido a ciertos datos que llaman la antencion como el que tiene un maximo de 110 habitaciones, otro con 0 Baños y el de 2m de Área

# %%
inmuebles.loc[inmuebles.Habitaciones == 110] #loc metodo para localizar
# Out:
#      Tipo                Descripcion  Habitaciones  Banos  Area    Barrio  \
# 897  Casa  Casa en venta en La Uribe           110      2   110  La Uribe
#
#          UPZ          Valor Moneda     Precio  Precio_Millon
# 897  Usaquén  $ 480.000.000      $  480000000         480.00

# %%
inmuebles.loc[inmuebles.Banos == 0]
# Out:
#           Tipo                         Descripcion  Habitaciones  Banos  Area  \
# 2910  Edificio  Edificio en venta en Santa Barbara            22      0  1080
# 8193      Casa      Casa en venta en Puente Aranda            15      0   450
# 9451      Casa               Casa en venta en Bosa            10      0   540
#
#              Barrio                                             UPZ  \
# 2910  Santa Barbara           USAQUÉN: Country Club + Santa Bárbara
# 8193  Puente Aranda  PUENTE ARANDA: Zona Industrial + Puente Aranda
# 9451           Bosa                                    Bosa Central
#
#                 Valor Moneda      Precio  Precio_Millon
# 2910  $ 9.200.000.000      $  9200000000        9200.00
# 8193  $ 1.000.000.000      $  1000000000        1000.00
# 9451    $ 800.000.000      $   800000000         800.00

# %%
inmuebles.loc[inmuebles.Area == 2]
# Out:
#              Tipo                            Descripcion  Habitaciones  Banos  \
# 8401  Apartamento  Apartamento en venta en San Cristobal             3      1
#
#       Area         Barrio      UPZ          Valor Moneda     Precio  \
# 8401     2  San Cristobal  Sosiego  $ 180.000.000      $  180000000
#
#       Precio_Millon
# 8401         180.00

# %% [markdown]
# # Algunos Graficos
#
# Precio Millon

# %%
inmuebles['Precio_Millon'].plot.hist(bins=10) #bins -> barras separadas
# Out:
# <Axes: ylabel='Frequency'>

# %% [markdown]
# Mejorando este grafico utilizando Seaborn

# %%
plt.figure(figsize=(10,6)) #lienzo
grafica = sns.histplot(data=inmuebles, x='Precio_Millon', kde=True, hue='Tipo') #kde -> Curva de densidad

grafica.set_title('Distribucion de los Valores de los Inmuebles en Bogotá')
plt.xlim((50,1000)) #limite
#plt.ylim((0,100))

plt.savefig('/content/drive/MyDrive/Inmersion Datos/inmuebles.png',format='png') #guardar grafico

plt.show()

# %% [markdown]
# Con este Histograma se buscaba mostrar el comportamiento del precio en los inmuebles

# %% [markdown]
# # **Desafíos:**
#
# 1.   Estudiar mejor el histograma de valores, seleccionar 3 tipos de inmuebles (Refinar el gráfico: Títulos, aumentar el tamaño de labels, colores, conclusión de la información)
#
# 2.   Precio del m2 por barrio y hacer el gráfico más adecuado para esta nueva variable.

# %%
inmuebles_desafio = inmuebles[inmuebles.Tipo.isin(['Lote', 'Bodega', 'Local'])]
inmuebles_desafio.head()
# Out:
#         Tipo                       Descripcion  Habitaciones  Banos  Area  \
# 330    Local       Local en venta en Chapinero             2      2    74
# 357   Bodega  Bodega en venta en Puente Aranda             3      2    68
# 1061  Bodega        Bodega en venta en Bochica             4      4   420
# 1177   Local  Local en venta en Barrios Unidos            12      6   620
# 1305   Local       Local en venta en Chapinero             1      2   250
#
#               Barrio                                             UPZ  \
# 330        Chapinero              CHAPINERO: Pardo Rubio + Chapinero
# 357    Puente Aranda  PUENTE ARANDA: Zona Industrial + Puente Aranda
# 1061         Bochica                                         Bolivia
# 1177  Barrios Unidos                                       Los Andes
# 1305       Chapinero              CHAPINERO: Pardo Rubio + Chapinero
#
#                 Valor Moneda      Precio  Precio_Millon
# ...

# %%
plt.figure(figsize=(10,6))
grafica_desafio = sns.histplot(data=inmuebles_desafio, x='Precio_Millon', kde=True, hue='Tipo', element="step", multiple="stack", palette = "rocket")

grafica_desafio.set_title('Distribucion de los Valores de los Inmuebles en Bogotá')
plt.xlim((50,6000))
plt.xlabel('Precio en Millones de Pesos Colombianos')
plt.ylabel('Cantidad de Inmuebles')
plt.savefig('/content/drive/MyDrive/Inmersion Datos/inmuebles_desafio.png',format='png')

plt.show()

# %% [markdown]
# Para el segundo desafio era necesario agregar una nueva columna con su respectivo calculo

# %%
inmuebles['Precio_m2'] = inmuebles['Precio_Millon'] / inmuebles['Area']
inmuebles.head()
# Out:
#           Tipo                                 Descripcion  Habitaciones  \
# 0  Apartamento  Apartamento en venta en Zona Noroccidental             3
# 1         Casa                   Casa en venta en Castilla             4
# 2  Apartamento     Apartamento en venta en Chico Reservado             3
# 3  Apartamento             Apartamento en venta en Usaquén             3
# 4  Apartamento         Apartamento en venta en Bella Suiza             2
#
#    Banos  Area              Barrio                                    UPZ  \
# 0      2    70  Zona Noroccidental     CHAPINERO: Pardo Rubio + Chapinero
# 1      3   170            Castilla            KENNEDY: Castilla + Bavaria
# 2      3   144     Chico Reservado     CHAPINERO: Chicó Lago + El Refugio
# 3      2   154             Usaquén                                Usaquén
# 4      3   128         Bella Suiza  USAQUÉN: Country Club + Santa Bárbara
#
#              Valor Moneda      Precio  Precio_Millon  Precio_m2
# ...

# %%
precio_m2_inmuebles=inmuebles[['Barrio','Precio_m2']].groupby(['Barrio']).mean().sort_values(by=['Precio_m2'], ascending=False).head(10)

precio_m2_inmuebles.plot(kind='bar', color = "darkseagreen")

plt.xlabel('Barrio')
plt.ylabel('Precio m2 promedio')
plt.title('10 Barrios de mayor precio por metro cuadrado')
plt.savefig('/content/drive/MyDrive/Inmersion Datos/inmuebles_desafio2.png',format='png')
plt.show()

# %% [markdown]
# # Aula 3

# %%
inmuebles.groupby('Barrio').mean() #cuando se use el groupby es necesario tambien el mean
# Out:
# <ipython-input-144-4722095e6fed>:1: FutureWarning: The default value of numeric_only in DataFrameGroupBy.mean is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   inmuebles.groupby('Barrio').mean() #cuando se use el groupby es necesario tambien el mean
#                     Habitaciones  Banos   Area  Precio_Millon  Precio_m2
# Barrio
# Alameda                     3.00   2.00  97.00         580.00       5.98
# Alhambra                    3.00   2.94 190.41         752.35       4.33
# Andes Norte                 3.00   2.86 124.86         709.57       6.05
# Antonio Nariño              4.31   2.50 163.06         459.22       3.53
# Barrancas                   2.87   2.13  70.20         314.13       4.42
# ...                          ...    ...    ...            ...        ...
# Villa Maria                 4.69   3.69 207.15         402.85       2.04
# ...

# %% [markdown]
# La manera para solucionar el segundo Desafio del Aula 2:

# %% [markdown]
# Se suman todos los inmuebles que pertenecen a cada Barrio, tambien su precio y se van a divir entre la sumatoria de toda la superficies que pertenecen a su Barrio, y asi para calcular el valor especifico del m2 de cada uno de los Barrios

# %%
datos_barrio = inmuebles.groupby('Barrio').sum()
datos_barrio
# Out:
# <ipython-input-145-45bba8259daf>:1: FutureWarning: The default value of numeric_only in DataFrameGroupBy.sum is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   datos_barrio = inmuebles.groupby('Barrio').sum()
#                     Habitaciones  Banos    Area  Precio_Millon  Precio_m2
# Barrio
# Alameda                        3      2      97         580.00       5.98
# Alhambra                      51     50    3237       12790.00      73.56
# Andes Norte                   21     20     874        4967.00      42.35
# Antonio Nariño               207    120    7827       22042.65     169.47
# Barrancas                     43     32    1053        4712.00      66.24
# ...                          ...    ...     ...            ...        ...
# Villa Maria                   61     48    2693        5237.00      26.58
# ...

# %% [markdown]
# **Nuevo DataSet**
#
# Apartir de estas sumas se agregara una nueva columna a este data set ***datos_barrio*** en donde se volvera a calcular el Precio/m2

# %%
datos_barrio['Valor_m2_Barrio'] = datos_barrio['Precio_Millon']/datos_barrio['Area']
datos_barrio
# Out:
#                     Habitaciones  Banos    Area  Precio_Millon  Precio_m2  \
# Barrio
# Alameda                        3      2      97         580.00       5.98
# Alhambra                      51     50    3237       12790.00      73.56
# Andes Norte                   21     20     874        4967.00      42.35
# Antonio Nariño               207    120    7827       22042.65     169.47
# Barrancas                     43     32    1053        4712.00      66.24
# ...                          ...    ...     ...            ...        ...
# Villa Maria                   61     48    2693        5237.00      26.58
# Villas De Granada             76     51    1905        6210.62      69.71
# Villemar                      53     37    1384        5469.00      71.81
# Zona Franca                    2      1      54         160.00       2.96
# Zona Noroccidental          2778   2204  119084      544453.06    4049.16
#
#                     Valor_m2_Barrio
# Barrio
# ...

# %% [markdown]
# Se mapearan estos datos
#
# Primero se almacena en un diccionario, teniendo como Key: Barrio, Valor: Precio x m2 (del dataset anterior)

# %%
m2_barrio = dict(datos_barrio['Valor_m2_Barrio'])

# %% [markdown]
# Ahora se busca llevar este nuevo valor al DataSet orginala.
#
# Se sustituye *Barrio*  por *Valor_m2_Barrio*, duplicando una columna (Barrios) y se asigna a la del m2

# %%
inmuebles['Valor_m2_Barrio'] = inmuebles['Barrio']
inmuebles['Valor_m2_Barrio'] = inmuebles['Valor_m2_Barrio'].map(m2_barrio) #map toma los valor de dict
inmuebles.head(5)
# Out:
#           Tipo                                 Descripcion  Habitaciones  \
# 0  Apartamento  Apartamento en venta en Zona Noroccidental             3
# 1         Casa                   Casa en venta en Castilla             4
# 2  Apartamento     Apartamento en venta en Chico Reservado             3
# 3  Apartamento             Apartamento en venta en Usaquén             3
# 4  Apartamento         Apartamento en venta en Bella Suiza             2
#
#    Banos  Area              Barrio                                    UPZ  \
# 0      2    70  Zona Noroccidental     CHAPINERO: Pardo Rubio + Chapinero
# 1      3   170            Castilla            KENNEDY: Castilla + Bavaria
# 2      3   144     Chico Reservado     CHAPINERO: Chicó Lago + El Refugio
# 3      2   154             Usaquén                                Usaquén
# 4      3   128         Bella Suiza  USAQUÉN: Country Club + Santa Bárbara
#
#              Valor Moneda      Precio  Precio_Millon  Precio_m2  \
# ...

# %% [markdown]
# Ahora se busca visualizar el Top 10 de Barrios que contienen más inmuebles a la venta

# %%
top_barrios = inmuebles['Barrio'].value_counts()[:10].index #obtiene el top 10 de Barrio

# %% [markdown]
# Como en el nuevo DataSet ***datos_barrio*** el Barrio aparece como indice, para quitarlo se hace lo siguente

# %%
datos_barrio.reset_index(inplace=True)
datos_barrio
# Out:
#                  Barrio  Habitaciones  Banos    Area  Precio_Millon  \
# 0               Alameda             3      2      97         580.00
# 1              Alhambra            51     50    3237       12790.00
# 2           Andes Norte            21     20     874        4967.00
# 3        Antonio Nariño           207    120    7827       22042.65
# 4             Barrancas            43     32    1053        4712.00
# ..                  ...           ...    ...     ...            ...
# 144         Villa Maria            61     48    2693        5237.00
# 145   Villas De Granada            76     51    1905        6210.62
# 146            Villemar            53     37    1384        5469.00
# 147         Zona Franca             2      1      54         160.00
# 148  Zona Noroccidental          2778   2204  119084      544453.06
#
#      Precio_m2  Valor_m2_Barrio
# 0         5.98             5.98
# 1        73.56             3.95
# 2        42.35             5.68
# ...

# %% [markdown]
# Se realiza consultas al Nuevo DataSet utilizando ***.query*** para obtener el Top 10 de Barrios

# %%
datos_barrio.query('Barrio in @top_barrios')
# Out:
#                  Barrio  Habitaciones  Banos    Area  Precio_Millon  \
# 5        Barrios Unidos          1525   1196   87799      259877.76
# 10                 Bosa          1743    789   34879       93400.56
# 22             Cedritos          1458   1348   53711      270027.73
# 24            Chapinero           892    913   81248      372130.93
# 50             Engativa          1676   1077   59808      172711.73
# 63              Kennedy          2151   1233   61475      207963.65
# 125       Santa Barbara          1073   1162   54693      320097.80
# 132                Suba          1497   1202   61615      266406.04
# 138             Usaquén          3109   3044  148121      837710.36
# 148  Zona Noroccidental          2778   2204  119084      544453.06
#
#      Precio_m2  Valor_m2_Barrio
# 5      2070.61             2.96
# 10     1654.36             2.68
# 22     2853.23             5.03
# 24     2466.03             4.58
# 50     1795.71             2.89
# ...

# %% [markdown]
# ##  Graficos del Segundo Desafio de Aula 2

# %%
plt.figure(figsize=(10,8))
ax = sns.barplot(data = datos_barrio.query('Barrio in @top_barrios'), x='Barrio', y='Valor_m2_Barrio') #Se urilizo la consulta anterio como data
ax.tick_params(axis='x', rotation=45) #ticks --> indicadores, axis -> eje

# %%
plt.figure(figsize=(10,8))
ax = sns.boxplot(x="Barrio", y="Precio_m2", data = inmuebles.query('Barrio in @top_barrios')) #boxplot muestra valores min y max como .describe()
ax.tick_params(axis='x', rotation=45)
plt.show()

# %%
plt.figure(figsize=(10,8))
ax = sns.boxplot(x="Barrio", y="Precio_m2", data = inmuebles.query('Barrio in @top_barrios & Precio_m2 < 15'))
ax.tick_params(axis='x', rotation=45)
plt.show()

# %%
plt.figure(figsize=(10,8))
ax = sns.boxplot(x="Barrio", y="Area", data = inmuebles.query('Barrio in @top_barrios & Area < 500'))
ax.tick_params(axis='x', rotation=45)
plt.show()

# %%
plt.figure(figsize=(10,8))
ax = sns.boxplot(x="Barrio", y="Precio_Millon", data = inmuebles.query('Barrio in @top_barrios & Precio_Millon < 2000'))
ax.tick_params(axis='x', rotation=45)
plt.show()

# %% [markdown]
#  # Nuevas Variables

# %% [markdown]
# Vamos a traer datos estadísticos de la ciudad de Bogotá, directamente del DANE y vamos a ver como estos datos nos ayudarían en inclusión de nuevas variables para el cálculo del precio de los inmuebles en la ciudad de Bogotá.
#
# Encuesta Multiproposito de Bogotá para obtener información socio-económica y de entorno urbano de los habitantes de Bogotá para la formulación, seguimiento y evaluación de las políticas distritales.
#
# https://microdatos.dane.gov.co/index.php/catalog/743

# %%
datos_raw = pd.read_csv('/content/drive/MyDrive/Inmersion Datos/Identificación (Capítulo A).csv', sep = ';', encoding ='latin-1') #encoding -> codigo en el que esta escrito
datos_raw.head()
# Out:
#    DIRECTORIO  DPTO   MPIO  CLASE  COD_LOCALIDAD NOMBRE_LOCALIDAD  \
# 0  3004346.00    11  11001      1           3.00         Santa Fe
# 1  3004347.00    11  11001      1          14.00     Los Mártires
# 2  3004348.00    11  11001      1           3.00         Santa Fe
# 3  3004349.00    11  11001      1           1.00          Usaquén
# 4  3004350.00    11  11001      1           1.00          Usaquén
#
#    COD_UPZ_GRUPO                        NOMBRE_UPZ_GRUPO  ESTRATO2021  \
# 0         814.00  SANTA FE: Las Nieves + Sagrado Corazón     11001187
# 1          37.00                            Santa Isabel     11001162
# 2         814.00  SANTA FE: Las Nieves + Sagrado Corazón     11001187
# 3         803.00   USAQUÉN: Country Club + Santa Bárbara     11001176
# 4         803.00   USAQUÉN: Country Club + Santa Bárbara     11001176
#
#                            NOMBRE_ESTRATO             FEX_C
# 0  SANTA FE: Las Nieves + Sagrado Corazón  13,2266692027239
# ...

# %%
datos_raw.shape
# Out:
# (106467, 11)

# %% [markdown]
# Se localiza el distrito y asi se eliminan los datos del area rural

# %%
datos_raw = datos_raw.loc[datos_raw.MPIO == 11001]
datos_raw.shape
# Out:
# (86504, 11)

# %% [markdown]
# Se importan los demas datos del DANE

# %%
datos_b = pd.read_csv('/content/drive/MyDrive/Inmersion Datos/Datos de la vivenda y su entorno (Capítulo B).csv',sep=';',encoding='latin-1')
datos_c = pd.read_csv('/content/drive/MyDrive/Inmersion Datos/Condiciones habitacionales del hogar (Capítulo C).csv',sep=';',encoding='latin-1')
datos_e = pd.read_csv('/content/drive/MyDrive/Inmersion Datos/Composición del hogar y demografía (Capítulo E).csv',sep=';',encoding='latin-1')
datos_h = pd.read_csv('/content/drive/MyDrive/Inmersion Datos/Educación (Capitulo H).csv',sep=';',encoding='latin-1')
datos_l = pd.read_csv('/content/drive/MyDrive/Inmersion Datos/Percepción sobre las condiciones de vida y el desempeño institucional (Capítulo L).csv',sep=';',encoding='latin-1')
datos_k = pd.read_csv('/content/drive/MyDrive/Inmersion Datos/Fuerza de trabajo (Capítulo K).csv',sep=';',encoding='latin-1')
# Out:
# <ipython-input-160-d9baa370190d>:2: DtypeWarning: Columns (4,25,30,47) have mixed types. Specify dtype option on import or set low_memory=False.
#   datos_c = pd.read_csv('/content/drive/MyDrive/Inmersion Datos/Condiciones habitacionales del hogar (Capítulo C).csv',sep=';',encoding='latin-1')
# <ipython-input-160-d9baa370190d>:3: DtypeWarning: Columns (66) have mixed types. Specify dtype option on import or set low_memory=False.
#   datos_e = pd.read_csv('/content/drive/MyDrive/Inmersion Datos/Composición del hogar y demografía (Capítulo E).csv',sep=';',encoding='latin-1')
# <ipython-input-160-d9baa370190d>:4: DtypeWarning: Columns (26,81) have mixed types. Specify dtype option on import or set low_memory=False.
#   datos_h = pd.read_csv('/content/drive/MyDrive/Inmersion Datos/Educación (Capitulo H).csv',sep=';',encoding='latin-1')
# ...

# %% [markdown]
# Se agregaran los datos a un DataFrame
# (Directorio es el campo que relaciona las columnas)

# %%
datos_dane = pd.merge(datos_raw,datos_b,on='DIRECTORIO', how='left') #how='left' viene siendo similar a left join en SQL
datos_dane.shape
# Out:
# (86504, 73)

# %%
datos_dane = pd.merge(datos_dane,datos_c,on='DIRECTORIO', how='left')
datos_dane.shape
# Out:
# (87061, 214)

# %%
datos_dane = pd.merge(datos_dane,datos_e,on='DIRECTORIO', how='left')
datos_dane.shape
# Out:
# <ipython-input-163-a8281422ec17>:1: FutureWarning: Passing 'suffixes' which cause duplicate columns {'FEX_C_x'} in the result is deprecated and will raise a MergeError in a future version.
#   datos_dane = pd.merge(datos_dane,datos_e,on='DIRECTORIO', how='left')
# (238559, 281)

# %%
datos_dane.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 238559 entries, 0 to 238558
# Columns: 281 entries, DIRECTORIO to FEX_C_y
# dtypes: float64(140), int64(126), object(15)
# memory usage: 513.3+ MB

# %% [markdown]
# **Desafío**
#
# 1. Dar un vistazo a la base de datos del DANE, entender estas variables conceptualmente para entender mejor el contexto de esta base.
# 2.  Organizar tu notebook para que tu proyecto quede mejor presentado.

# %% [markdown]
# # Aula 4

# %% [markdown]
# DataSet Dane ya tratado previamente

# %%
datos_dane = pd.read_csv('/content/drive/MyDrive/Inmersion Datos/datos_dane.csv')
datos_dane.head()
# Out:
#    DIRECTORIO NOMBRE_LOCALIDAD                                 NOMBRE_ESTRATO  \
# 0  3004368.00          Usaquén  USAQUÉN: Paseo de Los Libertadores + La Uribe
# 1  3004369.00          Usaquén                                        Usaquén
# 2  3004375.00        Chapinero             CHAPINERO: Pardo Rubio + Chapinero
# 3  3004380.00          Usaquén                                     Los Cedros
# 4  3004383.00         Fontibón                      Ciudad Salitre Occidental
#
#    NVCBP4  NVCBP14A  NVCBP14D  NVCBP14E  NVCBP14G  NVCBP15A  NVCBP15C  ...  \
# 0       1         2         2         2         2         2         2  ...
# 1       1         2         2         2         2         2         2  ...
# 2       2         2         2         2         2         2         1  ...
# 3       1         2         2         2         2         2         2  ...
# 4       1         2         2         2         2         1         2  ...
#
# ...

# %%
datos_dane.shape
# Out:
# (9857, 55)

# %%
datos_dane.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 9857 entries, 0 to 9856
# Data columns (total 55 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   DIRECTORIO        9857 non-null   float64
#  1   NOMBRE_LOCALIDAD  9857 non-null   object
#  2   NOMBRE_ESTRATO    9857 non-null   object
#  3   NVCBP4            9857 non-null   int64
#  4   NVCBP14A          9857 non-null   int64
#  5   NVCBP14D          9857 non-null   int64
#  6   NVCBP14E          9857 non-null   int64
#  7   NVCBP14G          9857 non-null   int64
#  8   NVCBP15A          9857 non-null   int64
#  9   NVCBP15C          9857 non-null   int64
#  10  NVCBP15F          9857 non-null   int64
#  11  NVCBP15G          9857 non-null   int64
#  12  NVCBP16A3         9857 non-null   int64
#  13  NVCBP16A4         9857 non-null   int64
#  14  NPCKP17           9857 non-null   float64
#  15  NPCKP18           9857 non-null   float64
# ...

# %% [markdown]
# Se renombran columnas del DataSet con este diccionario

# %%
dic_dane = {
       'NVCBP4':'CONJUNTO_CERRADO',
       'NVCBP14A':'FABRICAS_CERCA', 'NVCBP14D':'TERMINALES_BUS', 'NVCBP14E':'BARES_DISCO',
       'NVCBP14G':'OSCURO_PELIGROSO', 'NVCBP15A':'RUIDO', 'NVCBP15C':'INSEGURIDAD',
       'NVCBP15F':'BASURA_INADECUADA', 'NVCBP15G':'INVASION','NVCBP16A3':'MOV_ADULTOS_MAYORES',
       'NVCBP16A4':'MOV_NINOS_BEBES',
       'NPCKP17':'OCUPACION','NPCKP18':'CONTRATO','NPCKP23':'SALARIO_MES',
       'NPCKP44A':'DONDE_TRABAJA', 'NPCKPN62A':'DECLARACION_RENTA',
       'NPCKPN62B':'VALOR_DECLARACION', 'NPCKP64A':'PERDIDA_TRABAJO_C19',
       'NPCKP64E':'PERDIDA_INGRESOS_C19',
       'NHCCP3':'TIENE_ESCRITURA', 'NHCCP6':'ANO_COMPRA', 'NHCCP7':'VALOR_COMPRA', 'NHCCP8_1':'HIPOTECA_CRED_BANCO',
       'NHCCP8_2':'OTRO_CRED_BANCO', 'NHCCP8_3':'CRED_FNA', 'NHCCP8_6':'PRESTAMOS_AMIGOS',
       'NHCCP8_7':'CESANTIAS', 'NHCCP8_8':'AHORROS', 'NHCCP8_9':'SUBSIDIOS',
       'NHCCP9':'CUANTO_PAGARIA_MENSUAL', 'NHCCP11':'PLANES_ADQUIRIR_VIVIENDA',
       'NHCCP11A':'MOTIVO_COMPRA', 'NHCCP12':'RAZON_NO_ADQ_VIV', 'NHCCP41':'TIENE_CARRO','NHCCP41A':'CUANTOS_CARROS',
       'NHCCP47A':'TIENE_PERROS', 'NHCCP47B':'TIENE_GATOS', 'NHCLP2A':'VICTIMA_ATRACO', 'NHCLP2B':'VICTIMA_HOMICIDIO',
       'NHCLP2C':'VICTIMA_PERSECUSION',
       'NHCLP2E':'VICTIMA_ACOSO', 'NHCLP4':'COMO_VIVE_ECON', 'NHCLP5':'COMO_NIVEL_VIDA',
       'NHCLP8AB':'REACCION_OPORTUNA_POLICIA', 'NHCLP8AE':'COMO_TRANSPORTE_URBANO', 'NHCLP10':'SON_INGRESOS_SUFICIENTES',
       'NHCLP11':'SE_CONSIDERA_POBRE', 'NHCLP29_1A':'MED_C19_TRABAJO',
       'NHCLP29_1C':'MED_C19_CAMBIO_VIVIENDA', 'NHCLP29_1E':'MED_C19_ENDEUDAMIENTO',
       'NHCLP29_1F':'MED_C19_VENTA_BIENES','NPCHP4':'NIVEL_EDUCATIVO'
       }

datos_dane = datos_dane.rename(columns=dic_dane)
datos_dane.columns
# Out:
# Index(['DIRECTORIO', 'NOMBRE_LOCALIDAD', 'NOMBRE_ESTRATO', 'CONJUNTO_CERRADO',
#        'FABRICAS_CERCA', 'TERMINALES_BUS', 'BARES_DISCO', 'OSCURO_PELIGROSO',
#        'RUIDO', 'INSEGURIDAD', 'BASURA_INADECUADA', 'INVASION',
#        'MOV_ADULTOS_MAYORES', 'MOV_NINOS_BEBES', 'OCUPACION', 'CONTRATO',
#        'SALARIO_MES', 'DONDE_TRABAJA', 'DECLARACION_RENTA',
#        'VALOR_DECLARACION', 'PERDIDA_TRABAJO_C19', 'PERDIDA_INGRESOS_C19',
#        'TIENE_ESCRITURA', 'ANO_COMPRA', 'VALOR_COMPRA', 'HIPOTECA_CRED_BANCO',
#        'OTRO_CRED_BANCO', 'CRED_FNA', 'PRESTAMOS_AMIGOS', 'CESANTIAS',
#        'AHORROS', 'SUBSIDIOS', 'CUANTO_PAGARIA_MENSUAL',
#        'PLANES_ADQUIRIR_VIVIENDA', 'MOTIVO_COMPRA', 'RAZON_NO_ADQ_VIV',
#        'TIENE_CARRO', 'CUANTOS_CARROS', 'TIENE_PERROS', 'TIENE_GATOS',
#        'VICTIMA_ATRACO', 'VICTIMA_HOMICIDIO', 'VICTIMA_PERSECUSION',
#        'VICTIMA_ACOSO', 'COMO_VIVE_ECON', 'COMO_NIVEL_VIDA',
#        'REACCION_OPORTUNA_POLICIA', 'COMO_TRANSPORTE_URBANO',
# ...

# %%
datos_dane.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 9857 entries, 0 to 9856
# Data columns (total 55 columns):
#  #   Column                     Non-Null Count  Dtype
# ---  ------                     --------------  -----
#  0   DIRECTORIO                 9857 non-null   float64
#  1   NOMBRE_LOCALIDAD           9857 non-null   object
#  2   NOMBRE_ESTRATO             9857 non-null   object
#  3   CONJUNTO_CERRADO           9857 non-null   int64
#  4   FABRICAS_CERCA             9857 non-null   int64
#  5   TERMINALES_BUS             9857 non-null   int64
#  6   BARES_DISCO                9857 non-null   int64
#  7   OSCURO_PELIGROSO           9857 non-null   int64
#  8   RUIDO                      9857 non-null   int64
#  9   INSEGURIDAD                9857 non-null   int64
#  10  BASURA_INADECUADA          9857 non-null   int64
#  11  INVASION                   9857 non-null   int64
#  12  MOV_ADULTOS_MAYORES        9857 non-null   int64
# ...

# %% [markdown]
# Se agrupa por nombres de UPZ algunas de estas caracteristicas, para obtener el promedio

# %%
datos_dane.groupby('NOMBRE_ESTRATO')[['CONJUNTO_CERRADO','INSEGURIDAD','TERMINALES_BUS','BARES_DISCO','RUIDO','OSCURO_PELIGROSO','SALARIO_MES','TIENE_ESCRITURA','PERDIDA_TRABAJO_C19','PERDIDA_INGRESOS_C19','PLANES_ADQUIRIR_VIVIENDA']].mean().head()
# Out:
#                                                   CONJUNTO_CERRADO  \
# NOMBRE_ESTRATO
# 20 de Julio                                                   1.89
# Américas                                                      1.38
# Apogeo                                                        1.65
# Arborizadora                                                  1.43
# BARRIOS UNIDOS: Parque Salitre + Doce de Octubre              1.37
#
#                                                   INSEGURIDAD  TERMINALES_BUS  \
# NOMBRE_ESTRATO
# 20 de Julio                                              1.19            1.85
# Américas                                                 1.25            1.98
# Apogeo                                                   1.30            1.75
# Arborizadora                                             1.30            1.95
# BARRIOS UNIDOS: Parque Salitre + Doce de Octubre         1.33            1.99
#
# ...

# %% [markdown]
# En las encuestas del Dane las encuestas tienes respuesta de si(1) y no(2), asi que se sustituyen todos los 2 --> 0

# %%
datos = datos_dane[['NOMBRE_ESTRATO','CONJUNTO_CERRADO','INSEGURIDAD','TERMINALES_BUS','BARES_DISCO','RUIDO','OSCURO_PELIGROSO',
                    'SALARIO_MES','TIENE_ESCRITURA','PERDIDA_TRABAJO_C19','PERDIDA_INGRESOS_C19','PLANES_ADQUIRIR_VIVIENDA']].replace(2,0)
datos
# Out:
#                                      NOMBRE_ESTRATO  CONJUNTO_CERRADO  \
# 0     USAQUÉN: Paseo de Los Libertadores + La Uribe                 1
# 1                                           Usaquén                 1
# 2                CHAPINERO: Pardo Rubio + Chapinero                 0
# 3                                        Los Cedros                 1
# 4                         Ciudad Salitre Occidental                 1
# ...                                             ...               ...
# 9852         SANTA FE: Las Nieves + Sagrado Corazón                 1
# 9853         SANTA FE: Las Nieves + Sagrado Corazón                 0
# 9854         SANTA FE: Las Nieves + Sagrado Corazón                 1
# 9855         SANTA FE: Las Nieves + Sagrado Corazón                 1
# 9856                                   Santa Isabel                 0
#
#       INSEGURIDAD  TERMINALES_BUS  BARES_DISCO  RUIDO  OSCURO_PELIGROSO  \
# ...

# %% [markdown]
# Se revisa que en el nombre no se ejecutara la sustitucion

# %%
datos.NOMBRE_ESTRATO.value_counts()
# Out:
# Niza                                                   243
# SUBA: La Academia + Guaymaral + San José de Bavaria    212
# CHAPINERO: Chicó Lago + El Refugio                     210
# Los Libertadores                                       208
# Modelia                                                205
#                                                       ...
# Tunjuelito                                              26
# Lourdes                                                 25
# Localidad Chapinero resto                               21
# Localidad Usaquén resto                                 10
# Localidad Santa Fe resto                                 8
# Name: NOMBRE_ESTRATO, Length: 102, dtype: int64

# %% [markdown]
# Se verifica de forma especifica para el caso de la colonia 20 de Julio

# %%
datos.loc[datos.NOMBRE_ESTRATO == '20 de Julio']
# Out:
#      NOMBRE_ESTRATO  CONJUNTO_CERRADO  INSEGURIDAD  TERMINALES_BUS  \
# 513     20 de Julio                 0            0               0
# 706     20 de Julio                 0            1               0
# 707     20 de Julio                 0            1               0
# 708     20 de Julio                 0            1               0
# 709     20 de Julio                 0            1               0
# ...             ...               ...          ...             ...
# 8372    20 de Julio                 0            1               0
# 8751    20 de Julio                 0            0               0
# 8752    20 de Julio                 0            1               0
# 8783    20 de Julio                 0            1               1
# 9287    20 de Julio                 0            1               0
#
#       BARES_DISCO  RUIDO  OSCURO_PELIGROSO  SALARIO_MES  TIENE_ESCRITURA  \
# 513             0      1                 0        98.00             1.00
# ...

# %% [markdown]
# Se calcula nuevamente el promedio

# %%
datos_tratados = datos.groupby('NOMBRE_ESTRATO')[['CONJUNTO_CERRADO','INSEGURIDAD','TERMINALES_BUS','BARES_DISCO','RUIDO','OSCURO_PELIGROSO',
                                      'SALARIO_MES','TIENE_ESCRITURA','PERDIDA_TRABAJO_C19','PERDIDA_INGRESOS_C19','PLANES_ADQUIRIR_VIVIENDA']].mean()
datos_tratados
# Out:
#                                                   CONJUNTO_CERRADO  \
# NOMBRE_ESTRATO
# 20 de Julio                                                   0.11
# Américas                                                      0.62
# Apogeo                                                        0.35
# Arborizadora                                                  0.57
# BARRIOS UNIDOS: Parque Salitre + Doce de Octubre              0.63
# ...                                                            ...
# Usaquén                                                       0.90
# Venecia                                                       0.47
# Verbenal                                                      0.77
# Zona Franca                                                   0.94
# Álamos                                                        0.65
#
#                                                   INSEGURIDAD  TERMINALES_BUS  \
# NOMBRE_ESTRATO
# ...

# %% [markdown]
# ## Fusion de los DataSet
#
# Se fusionan de Datos de los Inmuebles con los Datos Dane ya tratados.
#
# Siendo la UPZ/NOMBRE_ESTRATO la columna que relaciona a ambos DataSet

# %%
pd.merge(inmuebles,datos_tratados, left_on='UPZ', right_on='NOMBRE_ESTRATO', how='left' )
# Out:
#              Tipo                                     Descripcion  \
# 0     Apartamento      Apartamento en venta en Zona Noroccidental
# 1            Casa                       Casa en venta en Castilla
# 2     Apartamento         Apartamento en venta en Chico Reservado
# 3     Apartamento                 Apartamento en venta en Usaquén
# 4     Apartamento             Apartamento en venta en Bella Suiza
# ...           ...                                             ...
# 9515  Apartamento                 Apartamento en venta en Kennedy
# 9516  Apartamento  Apartamento en venta en Parque Central Bavaria
# 9517        Local                      Local en venta en Restrepo
# 9518         Casa                       Casa en venta en Engativa
# 9519  Apartamento                 Apartamento en venta en Tintala
#
#       Habitaciones  Banos  Area                  Barrio  \
# 0                3      2    70      Zona Noroccidental
# 1                4      3   170                Castilla
# ...

# %% [markdown]
# NOMBRE_ESTRATO deja de aparecer ya que el sistema sabe que es UPZ

# %%
datos_ml = pd.merge(inmuebles,datos_tratados, left_on='UPZ', right_on='NOMBRE_ESTRATO', how='left' )
datos_ml.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 9520 entries, 0 to 9519
# Data columns (total 24 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   Tipo                      9520 non-null   object
#  1   Descripcion               9520 non-null   object
#  2   Habitaciones              9520 non-null   int64
#  3   Banos                     9520 non-null   int64
#  4   Area                      9520 non-null   int64
#  5   Barrio                    9520 non-null   object
#  6   UPZ                       9478 non-null   object
#  7   Valor                     9520 non-null   object
#  8   Moneda                    9520 non-null   object
#  9   Precio                    9520 non-null   object
#  10  Precio_Millon             9520 non-null   float64
#  11  Precio_m2                 9520 non-null   float64
#  12  Valor_m2_Barrio           9520 non-null   float64
# ...

# %% [markdown]
# Para el modelo de ML se traen los codigos de cada UPZ
#
# > Bloque con sangría

# %%
upz = pd.read_csv('/content/drive/MyDrive/Inmersion Datos/cod_upz.csv')
upz.head()
# Out:
#                            NOMBRE_ESTRATO  COD_UPZ_GRUPO
# 0  SANTA FE: Las Nieves + Sagrado Corazón         814.00
# 1                            Santa Isabel          37.00
# 2   USAQUÉN: Country Club + Santa Bárbara         803.00
# 3      CHAPINERO: Pardo Rubio + Chapinero         816.00
# 4               Ciudad Salitre Occidental         110.00

# %% [markdown]
# Se traen los codigos de las UPZ al nuevo DataSet a utilizar, sin embargo en el DataSet Inmuebles no todas las UPZ fueron contempladas en la encuenta del Dane, por lo que para ello se utiliza un ***inner join*** para traer la interseccion de las UPZ que contengan datos en el conjuto del Dane DataSet y que si tengan su codigo de UPZ para elaborar el modelo de ML.
#
# Se utilizara un modelo de regresion lineal por lo que se necesitan valores numericos.

# %%
datos_ml = pd.merge(datos_ml, upz, left_on='UPZ', right_on='NOMBRE_ESTRATO', how='inner')
datos_ml.head()
# Out:
#           Tipo                                 Descripcion  Habitaciones  \
# 0  Apartamento  Apartamento en venta en Zona Noroccidental             3
# 1         Casa                      Casa en venta en Marly             3
# 2         Casa         Casa en venta en Zona Noroccidental             3
# 3  Apartamento  Apartamento en venta en Zona Noroccidental             2
# 4         Casa         Casa en venta en Zona Noroccidental             3
#
#    Banos  Area              Barrio                                 UPZ  \
# 0      2    70  Zona Noroccidental  CHAPINERO: Pardo Rubio + Chapinero
# 1      3   147               Marly  CHAPINERO: Pardo Rubio + Chapinero
# 2      4   300  Zona Noroccidental  CHAPINERO: Pardo Rubio + Chapinero
# 3      1    45  Zona Noroccidental  CHAPINERO: Pardo Rubio + Chapinero
# 4      6   380  Zona Noroccidental  CHAPINERO: Pardo Rubio + Chapinero
#
#              Valor Moneda      Precio  ...  BARES_DISCO  RUIDO  \
# ...

# %%
datos_ml.shape
# Out:
# (9318, 26)

# %%
datos_ml.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 9318 entries, 0 to 9317
# Data columns (total 26 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   Tipo                      9318 non-null   object
#  1   Descripcion               9318 non-null   object
#  2   Habitaciones              9318 non-null   int64
#  3   Banos                     9318 non-null   int64
#  4   Area                      9318 non-null   int64
#  5   Barrio                    9318 non-null   object
#  6   UPZ                       9318 non-null   object
#  7   Valor                     9318 non-null   object
#  8   Moneda                    9318 non-null   object
#  9   Precio                    9318 non-null   object
#  10  Precio_Millon             9318 non-null   float64
#  11  Precio_m2                 9318 non-null   float64
#  12  Valor_m2_Barrio           9318 non-null   float64
# ...

# %% [markdown]
# Se realiza un grafico para ir vizualizando los cambios realizados

# %%
plt.figure(figsize=(10,8))
sns.boxplot(data = datos_ml, y='Precio_Millon')
plt.show()

# %% [markdown]
# #  Limite de Datos
#
# Se realiza un query para limitar Precio_Millon, normalizando los datos evitando esa dispercion y teniendo una media mas exacta

# %%
#5000
datos_ml = datos_ml.query('Precio_Millon < 1200 & Precio_Millon > 60')
datos_ml
# Out:
#              Tipo                                 Descripcion  Habitaciones  \
# 0     Apartamento  Apartamento en venta en Zona Noroccidental             3
# 1            Casa                      Casa en venta en Marly             3
# 3     Apartamento  Apartamento en venta en Zona Noroccidental             2
# 9            Casa         Casa en venta en Zona Noroccidental             5
# 10    Apartamento  Apartamento en venta en Zona Noroccidental             3
# ...           ...                                         ...           ...
# 9313  Apartamento            Apartamento en venta en Verbenal             2
# 9314  Apartamento            Apartamento en venta en Verbenal             2
# 9315  Apartamento            Apartamento en venta en Verbenal             2
# 9316  Apartamento            Apartamento en venta en Verbenal             2
# 9317  Apartamento            Apartamento en venta en Verbenal             2
#
# ...

# %%
plt.figure(figsize=(10,8))
sns.boxplot(data = datos_ml, y='Precio_Millon')
plt.show()

# %% [markdown]
# Se cambia el salario por mes -> anual

# %%
datos_ml['SALARIO_ANUAL_MI'] = datos_ml['SALARIO_MES']*12/1000000
datos_ml['SALARIO_ANUAL_MI']
# Out:
# 0      48.42
# 1      48.42
# 3      48.42
# 9      48.42
# 10     48.42
#         ...
# 9313   29.34
# 9314   29.34
# 9315   29.34
# 9316   29.34
# 9317   29.34
# Name: SALARIO_ANUAL_MI, Length: 8313, dtype: float64

# %% [markdown]
# Se observa que no hya mucha relacion entre en Precio m2 (Valor_m2_Millon en la clase) y el salario anual de las personas

# %%
plt.figure(figsize=(10,8))
sns.scatterplot(data = datos_ml, x='SALARIO_ANUAL_MI', y='Precio_m2')
#plt.xlim(())
plt.ylim((0,15))
plt.show()

# %% [markdown]
# # Correlación de las variables

# %% [markdown]
# Se utiliza ***.corr*** para ver la relacion que hay entre dos variables
#
# *   Cercano a 1 -> correlacion directa
# *   si va a -1 -> correlacion indirecta
# *   0 -> no hay correlacion

# %%
datos_ml.corr()
# Out:
# <ipython-input-233-40ad07aae067>:1: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   datos_ml.corr()
#                           Habitaciones  Banos  Area  Precio_Millon  Precio_m2  \
# Habitaciones                      1.00   0.44  0.03           0.18      -0.31
# Banos                             0.44   1.00  0.04           0.66      -0.03
# Area                              0.03   0.04  1.00           0.04      -0.04
# Precio_Millon                     0.18   0.66  0.04           1.00       0.36
# Precio_m2                        -0.31  -0.03 -0.04           0.36       1.00
# Valor_m2_Barrio                  -0.21   0.13 -0.04           0.40       0.49
# CONJUNTO_CERRADO                 -0.12   0.16 -0.01           0.32       0.33
# INSEGURIDAD                       0.13  -0.19 -0.00          -0.37      -0.37
# ...

# %% [markdown]
# Más sobre Correlacion ->
# https://www.tylervigen.com/spurious-correlations

# %%
plt.figure(figsize=(18, 8))
#mascara = np.triu(np.ones_like(datos_ml.corr(), dtype=bool)) mask=mascara,
heatmap = sns.heatmap(datos_ml.corr(), vmin=-1, vmax=1, annot=True, cmap='BrBG')
heatmap.set_title('Correlación de las variables', fontdict={'fontsize':18}, pad=16);
# Out:
# <ipython-input-234-44633713b2b0>:3: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   heatmap = sns.heatmap(datos_ml.corr(), vmin=-1, vmax=1, annot=True, cmap='BrBG')

# %% [markdown]
# # Modelo de Machine Learning

# %% [markdown]
# Importar Librerias

# %%
from sklearn.linear_model import LinearRegression
from sklearn.model_selection import train_test_split #para el entrenamiento

# %% [markdown]
# Se busca predecir el Precio en Millon, utilizando en este caso el codigo UPZ para ver como ingluye en el precio la locacion de los inmuebles

# %%
X = datos_ml[['COD_UPZ_GRUPO']] #Linea Base X por que es matriz
y = datos_ml['Precio_Millon']

X_train, X_test, y_train, y_test = train_test_split(X,y,test_size=0.25,random_state=99) #test_size= Cantidad de datos (en este caso 25% de mis datos), random_state= estado de aleatoridad

# %%
X_train #75% de los datos
# Out:
#       COD_UPZ_GRUPO
# 1512         817.00
# 7864          85.00
# 6058          21.00
# 1683         817.00
# 2481          14.00
# ...             ...
# 6038          21.00
# 8875         102.00
# 2200          14.00
# 3883         803.00
# 8154          85.00
#
# [6234 rows x 1 columns]

# %%
X_test #25% de los datos
# Out:
#       COD_UPZ_GRUPO
# 6340          74.00
# 7805          85.00
# 4902          47.00
# 7041         100.00
# 2436          14.00
# ...             ...
# 3323          14.00
# 3945         803.00
# 5572          27.00
# 3633         803.00
# 3652         803.00
#
# [2079 rows x 1 columns]

# %%
y_train
# Out:
# 1512   1050.00
# 7864    129.00
# 6058    206.38
# 1683    650.00
# 2481    250.00
#          ...
# 6038    560.00
# 8875    560.00
# 2200    685.00
# 3883    850.00
# 8154    132.00
# Name: Precio_Millon, Length: 6234, dtype: float64

# %%
y_test #y de prueba
# Out:
# 6340   199.90
# 7805   120.80
# 4902   400.00
# 7041   340.00
# 2436   355.00
#         ...
# 3323   700.00
# 3945   510.00
# 5572   220.00
# 3633   420.00
# 3652   435.60
# Name: Precio_Millon, Length: 2079, dtype: float64

# %% [markdown]
# Regresion Lineal

# %%
modelo = LinearRegression()

# %% [markdown]
# Se ajustan datos de entremamiento

# %%
modelo.fit(X_train,y_train)
# Out:
# LinearRegression()

# %% [markdown]
# Se pone los datos con los que va a predecir los datos en y

# %%
y_predict_test = modelo.predict(X_test)

# %% [markdown]
# Validacion

# %%
from sklearn.metrics import mean_absolute_error, r2_score #metricas

baseline_mae = mean_absolute_error(y_test, y_predict_test) #Reducir elError
baseline_r2 = r2_score(y_test, y_predict_test) #Coeficiente de determinacion % (Que tan bien trabaja el modelo)
print(baseline_mae,baseline_r2)
# Out:
# 187.323609443345 0.031111799984413713

# %% [markdown]
# Se vuelve a iterar agregando dos variables nuevas

# %%
X = datos_ml[['COD_UPZ_GRUPO','Habitaciones','Banos']]

y = datos_ml["Precio_Millon"]

X_train, X_test, y_train, y_test = train_test_split(X, y, test_size = 0.25, random_state = 99)
modelo_1 = LinearRegression()
modelo_1.fit(X_train, y_train)
y_predict_test = modelo_1.predict(X_test)
y_predict_train = modelo_1.predict(X_train)
mae_test = mean_absolute_error(y_test, y_predict_test)
r2_test = r2_score(y_test, y_predict_test)
mae_train = mean_absolute_error(y_train, y_predict_train)
r2_train = r2_score(y_train, y_predict_train)
print(mae_test,r2_test)
print(mae_train,r2_train)
# Out:
# 129.79569561829595 0.4710300116377151
# 134.0676755859009 0.4669568993620524

# %% [markdown]
# Se agregan mas variables

# %%
X = datos_ml[['COD_UPZ_GRUPO','Habitaciones','Banos','CONJUNTO_CERRADO','SALARIO_ANUAL_MI','TIENE_ESCRITURA']]

y = datos_ml["Precio_Millon"]

X_train, X_test, y_train, y_test = train_test_split(X, y, test_size = 0.25, random_state = 99)
modelo_1 = LinearRegression()
modelo_1.fit(X_train, y_train)
y_predict_test = modelo_1.predict(X_test)
y_predict_train = modelo_1.predict(X_train)
mae_test = mean_absolute_error(y_test, y_predict_test)
r2_test = r2_score(y_test, y_predict_test)
mae_train = mean_absolute_error(y_train, y_predict_train)
r2_train = r2_score(y_train, y_predict_train)
print(mae_test,r2_test)
print(mae_train,r2_train)
# Out:
# 118.25967274431333 0.5404735562069192
# 123.22271988681676 0.5269614226488988

# %% [markdown]
# Prueba:
#
# *   Codigo UPZ 816
# *   3 Habitaciones
# *   2 Baños
# *   Conjunto Cerrado
# *   Gana $50 Millones al año
# *   Tiene Escritura
#
# Con estas caracteristicas ¿cuanto valdria un inmueble?

# %%
modelo_1.predict([[816,3,2,1,50,1]])
# Out:
# /usr/local/lib/python3.10/dist-packages/sklearn/base.py:439: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(
# array([434.21129691])
